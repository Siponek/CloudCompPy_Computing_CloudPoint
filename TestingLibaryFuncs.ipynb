# %% [markdown]
# Libs

# %%
from computeclouds import ComputeClouds
from datetime import datetime
import os
# Out:
# ComputeClouds_> Main : Libs loaded

# %%
path_to_file_original_1 = r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\river_1.txt"
path_to_file_original_2 = r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\river_2.txt"

# path_to_file_original_1 = r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\1_E_subsample.txt"
# path_to_file_original_2 = r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\2_E_subsample.txt"

path_to_params_file = r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt"

assert os.path.isfile(path_to_file_original_1), "File does not exist"
assert os.path.isfile(path_to_file_original_2), "File does not exist"
assert os.path.isfile(path_to_params_file), "File does not exist"
print("Paths are loaded", datetime.now() )
# Out:
# Paths are loaded 2022-07-19 15:49:23.053710

# %% [markdown]
# ### Parameters to change

# %%
m3c2_params_dic={}

m3c2_params_dic["M3C2VER"]= 1
m3c2_params_dic["NormalMode"]= 0
m3c2_params_dic["NormalScale"]= 10.691401
m3c2_params_dic["NormalMinScale"]= 5.3457
m3c2_params_dic["NormalStep"]= 5.3457
m3c2_params_dic["NormalMaxScale"]= 21.382801
m3c2_params_dic["SearchScale"]= 5.3457
m3c2_params_dic["SearchDepth"]= 41.898286
m3c2_params_dic["SubsampleRadius"]= 2.67285
m3c2_params_dic["NormalPreferedOri"]= 4
m3c2_params_dic["NormalUseCorePoints"]= "true"
m3c2_params_dic["SubsampleEnabled"]= "false"
m3c2_params_dic["RegistrationError"]= 0
m3c2_params_dic["RegistrationErrorEnabled"]= "false"
m3c2_params_dic["UseSinglePass4Depth"]= "false"
m3c2_params_dic["PositiveSearchOnly"]= "false"
m3c2_params_dic["UseMedian"]= "false"
m3c2_params_dic["UseMinPoints4Stat"]= "false"
m3c2_params_dic["MinPoints4Stat"]= 5
m3c2_params_dic["ProjDestIndex"]= 1
m3c2_params_dic["UseOriginalCloud"]= "false"
m3c2_params_dic["ExportStdDevInfo"]= "true"
m3c2_params_dic["ExportDensityAtProjScale"]= "true"
m3c2_params_dic["MaxThreadCount"]= 4
m3c2_params_dic["UsePrecisionMaps"]= "false"
m3c2_params_dic["PM1Scale"]= 1
m3c2_params_dic["PM2Scale"]= 1

# %%
# print(f"Writing parameters to {path_to_params_file}")

# with open(path_to_params_file, 'w') as f:
#     f.write("[General]\n")
#     for key,value in m3c2_params_dic.items():
#         f.write("%s=%s\n"%(key,value))

# %% [markdown]
# ### Constraining the cloud to a certain area

# %%
# #? data for the strap
# # Global center of the cloud
# X_glob =  503455.626160
# Y_glob =  4918094.496948
# Z_glob =  720.263306
# # dimmensions
# X_delta = 100
# Y_delta = 100
# Z_delta = 100
# # X: 683.566
# # Y: 522.363
# # Z: 345.093
# #                       c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/constrained_cloud.txt...
# path_to_output_cloud_1= r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\output_cloud_1.txt"
# path_to_output_cloud_2= r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\output_cloud_2.txt"

# %% [markdown]
# ### Specifying the cloud size/ box size

# %%
# bounding_box_list=[X_glob - X_delta, X_glob + X_delta, Y_glob - Y_delta, Y_glob + Y_delta, Z_glob - Z_delta, Z_glob + Z_delta]

# %% [markdown]
# ### Creating clouds with specified size

# %%
# path_to_constrained_1 = ComputeClouds.constrainCloud(path_to_cloud=path_to_file_original_1, bounding_box_list=bounding_box_list, path_to_output_cloud=path_to_output_cloud_1)
# path_to_constrained_2 = ComputeClouds.constrainCloud(path_to_cloud=path_to_file_original_2, bounding_box_list=bounding_box_list, path_to_output_cloud=path_to_output_cloud_2)
# # path_to_constrained_1 = ComputeClouds.constrainCloud(path_to_cloud=path_to_file_original_1, bounding_box_list=bounding_box_list, path_to_output_cloud=path_to_output_cloud)

# %% [markdown]
# ### Looping over the parameters

# %%
# with open("./log_timing.log", 'a') as f:
# with open("./log_timing.log", 'w') as f:
#     f.write("[Parameters]\t[BoxSize]\t[Time]\n")


m3c2_params_dic={}
m3c2_params_dic["M3C2VER"]= 1
m3c2_params_dic["NormalMode"]= 0
m3c2_params_dic["NormalScale"]= 10.691401
m3c2_params_dic["NormalMinScale"]= 5.3457
m3c2_params_dic["NormalStep"]= 5.3457
m3c2_params_dic["NormalMaxScale"]= 21.382801
m3c2_params_dic["SearchScale"]= 5.3457
m3c2_params_dic["SearchDepth"]= 41.898286
m3c2_params_dic["SubsampleRadius"]= 2.67285
m3c2_params_dic["NormalPreferedOri"]= 4
m3c2_params_dic["NormalUseCorePoints"]= "true"
m3c2_params_dic["SubsampleEnabled"]= "false"
m3c2_params_dic["RegistrationError"]= 0
m3c2_params_dic["RegistrationErrorEnabled"]= "false"
m3c2_params_dic["UseSinglePass4Depth"]= "false"
m3c2_params_dic["PositiveSearchOnly"]= "false"
m3c2_params_dic["UseMedian"]= "false"
m3c2_params_dic["UseMinPoints4Stat"]= "false"
m3c2_params_dic["MinPoints4Stat"]= 5
m3c2_params_dic["ProjDestIndex"]= 1
m3c2_params_dic["UseOriginalCloud"]= "false"
m3c2_params_dic["ExportStdDevInfo"]= "true"
m3c2_params_dic["ExportDensityAtProjScale"]= "true"
m3c2_params_dic["MaxThreadCount"]= 4
m3c2_params_dic["UsePrecisionMaps"]= "false"
m3c2_params_dic["PM1Scale"]= 1
m3c2_params_dic["PM2Scale"]= 1

# M3C2VER = 1
# NormalMode = 0
# NormalScale = 10.691401
# NormalMinScale = 5.3457
# NormalStep = 5.3457
# NormalMaxScale = 21.382801
# SearchScale = 5.3457
# SearchDepth = 41.898286
# SubsampleRadius = 2.67285
# NormalPreferedOri = 4
# NormalUseCorePoints = true
# SubsampleEnabled = false
# RegistrationError = 0
# RegistrationErrorEnabled = false
# UseSinglePass4Depth = false
# PositiveSearchOnly = false
# UseMedian = false
# UseMinPoints4Stat = false
# MinPoints4Stat = 5
# ProjDestIndex = 1
# UseOriginalCloud = false
# ExportStdDevInfo = true
# ExportDensityAtProjScale = true
# MaxThreadCount = 4
# UsePrecisionMaps = false
# PM1Scale = 1
# PM2Scale = 1
ComputeClouds.overwrite_parameters(path_to_params_file, m3c2_params_dic)
# Out:
# 'C:\\Users\\szinp\\Desktop\\GIS_PROJECT\\CloudComPy39_20220513\\CloudCompPy_Computing-CloudPoint\\dataFolder\\PythonParameters\\m3c2_params.txt'

# %% [markdown]
# ### Calculating M3C2

# %% [markdown]
# ```
# TODO:
# - created a bounding box for the cloud
# - logging for checking the performance
# - created m3c2 outputs for iterating parameters
# - repeated for moving the boudnign box (to see if performance/output changes)
# ```

# %%
# bounding_box_list_volume = (bounding_box_list[1] - bounding_box_list[0]) * (bounding_box_list[3] - bounding_box_list[2]) * (bounding_box_list[5] - bounding_box_list[4])

# %%
# my_file = open("this_is_file.txt","w+")
# my_file.write("Hello World")
# my_file.close()
path_for_logging = os.path.abspath(".")
path_for_logging_folder = path_for_logging + "\dataFolder\parametersTests"

if not os.path.exists(path_for_logging_folder):
    os.makedirs(path_for_logging_folder)
iteration : int = 0
for x in range(0,7):
    # if x<2:
    #     continue
    path_for_logging = path_for_logging_folder + "\log_timing_3_375_000_volume" + str(x+1) + ".log"
    with open(path_for_logging, "w+") as f:
        list_of_changed_params = []
        f.write("[NormalScale NormalMinScale NormalStep NormalMaxScale SearchScale SearchDepth SubsampleRadius]\t[BoxSize]\t[Time]\n")
        
        m3c2_params_dic["NormalScale"]= 3
        m3c2_params_dic["NormalMinScale"]= 3.3457
        m3c2_params_dic["NormalStep"]= 3.3457
        m3c2_params_dic["NormalMaxScale"]= 13.382801
        m3c2_params_dic["SearchScale"]= 5
        m3c2_params_dic["SearchDepth"]= 13.898286
        m3c2_params_dic["SubsampleRadius"]= 0.67285

        # dimmensions
        # Once variant for checking if the box size matter
        if x >= 4:
            print("Calculating box number 2")
            X_glob =  2707309.209991 + iteration*25
            Y_glob =  1093859.170044 - iteration*25
            Z_glob =  274.464996 - iteration*25
            X_delta = 50+50
            Y_delta = 50+50
            Z_delta = 50+50
            iteration += 1
        else:
            print("Calculating box number 1")
            X_glob =  2707309.209991 + x*25
            Y_glob =  1093859.170044 - x*25
            Z_glob =  274.464996 - x*25
            X_delta = 50
            Y_delta = 50
            Z_delta = 50

        path_to_output_cloud_1= r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_1.txt"
        path_to_output_cloud_2= r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_2.txt"

        bounding_box_list=[X_glob - X_delta, X_glob + X_delta, Y_glob - Y_delta, Y_glob + Y_delta, Z_glob - Z_delta, Z_glob + Z_delta]
        bounding_box_list_volume = (bounding_box_list[1] - bounding_box_list[0]) * (bounding_box_list[3] - bounding_box_list[2]) * (bounding_box_list[5] - bounding_box_list[4])

        #* Creating two new constrained clouds
        path_to_constrained_1 = ComputeClouds.constrainCloud(path_to_cloud=path_to_file_original_1, bounding_box_list=bounding_box_list, path_to_output_cloud=path_to_output_cloud_1)
        path_to_constrained_2 = ComputeClouds.constrainCloud(path_to_cloud=path_to_file_original_2, bounding_box_list=bounding_box_list, path_to_output_cloud=path_to_output_cloud_2)
        #* Loop for changing parameters
        for iteration in range(1, 31):
            # * parameters to be changed
            # * rest of them are declared earlier
            nameOfFileOutput = (
                "dataFolder/parametersTests/output_" +  str(x+1) + "_"+ str(iteration) + ".las"
            )
            m3c2_params_dic["NormalScale"] += 1
            m3c2_params_dic["NormalMinScale"] += 1
            m3c2_params_dic["NormalStep"] += 1
            m3c2_params_dic["NormalMaxScale"] += 1
            m3c2_params_dic["SearchScale"] += 1
            # m3c2_params_dic["SearchDepth"] += 1
            m3c2_params_dic["SubsampleRadius"] += 1
            list_of_changed_params = [
                m3c2_params_dic["NormalScale"],
                m3c2_params_dic["NormalMinScale"],
                m3c2_params_dic["NormalStep"],
                m3c2_params_dic["NormalMaxScale"],
                m3c2_params_dic["SearchScale"],
                m3c2_params_dic["SearchDepth"],
                m3c2_params_dic["SubsampleRadius"],
            ]

            # * create new parameters file
            ComputeClouds.overwrite_parameters(
                path_to_params_file, m3c2_params_dic
            )
            # * run M3C2
            time_startM3C2 = ComputeClouds.perf_counter()
            ComputeClouds.calcM3C2(
                firstCd=path_to_constrained_1,
                secondCd=path_to_constrained_2,
                parametersConfigFilePath=path_to_params_file,
                nameOfFileOutput=nameOfFileOutput, verbose=False
            )
            time_endM3C2 = ComputeClouds.perf_counter() - time_startM3C2
            f.write(
                f"{list_of_changed_params}\t{bounding_box_list_volume}\t{time_endM3C2}\n"
            )

        print("Done")
# Out:
# Calculating box number 1
# Constraining cloud C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\river_1.txt
# Output cloud C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_1.txt
# Data loaded
# Data1:  736474
# data1_list length:  736474
# data1_list[:10]:  [[2707118.8215692905, 1093776.8059870184, 259.0814176520512], [2707119.7413692907, 1093776.6804870185, 258.95931765205114], [2707120.5755692907, 1093776.4740870185, 259.00181765205116], [2707119.2593692904, 1093776.8218870184, 259.08751765205113], [2707118.390469291, 1093776.8411870184, 259.05241765205113], [2707115.2549692905, 1093776.9153870186, 259.12351765205113], [2707120.0702692904, 1093776.9311870185, 258.75931765205115], [2707117.5043692905, 1093776.7713870185, 259.0667176520512], [2707120.1600692905, 1093776.4387870184, 258.98301765205116], [2707116.0534692905, 1093776.9011870185, 259.0565176520512]]
# File read and converted in: 7.0067308000000015
# Filtering
#  14%|█▍        | 101511/736474 [00:00<00:03, 195765.75it/s]
# Filtering done
# Filtered_data1_list len:  101511
# Filtering done in:  0.5338550000000026
# Saving filtered data to C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_1.txt...
# Done saving filtered data
# Constraining cloud C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\river_2.txt
# Output cloud C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_2.txt
# Data loaded
# Data1:  957402
# data1_list length:  957402
# data1_list[:10]:  [[2707100.8, 1093803.9199932863, 253.1900000667572], [2707100.97, 1093802.8099932862, 253.05000006675718], [2707099.67, 1093803.499993286, 253.1300000667572], [2707099.07, 1093803.729993286, 253.1200000667572], [2707098.67, 1093802.8899932862, 253.05000006675718], [2707098.14, 1093804.3099932862, 253.1000000667572], [2707098.29, 1093803.3599932862, 253.1300000667572], [2707100.75, 1093802.3299932862, 253.0400000667572], [2707099.82, 1093802.519993286, 253.0900000667572], [2707099.23, 1093802.6399932862, 253.02000006675718]]
# File read and converted in: 7.917104200000001
# Filtering
#  13%|█▎        | 123590/957402 [00:00<00:04, 205599.14it/s]
# Filtering done
# Filtered_data1_list len:  123590
# Filtering done in:  0.611200199999999
# Saving filtered data to C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_2.txt...
# Done saving filtered data
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_1.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_2.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_3.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_4.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_5.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_6.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_7.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_8.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_9.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_10.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_11.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_12.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_13.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_14.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_15.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_16.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_17.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_18.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_19.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_20.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_21.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_22.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_23.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_24.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_25.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_26.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_27.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_28.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_29.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_1_30.las
#  Job finished
# Done
# Calculating box number 1
# Constraining cloud C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\river_1.txt
# Output cloud C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_1.txt
# Data loaded
# Data1:  736474
# data1_list length:  736474
# data1_list[:10]:  [[2707118.8215692905, 1093776.8059870184, 259.0814176520512], [2707119.7413692907, 1093776.6804870185, 258.95931765205114], [2707120.5755692907, 1093776.4740870185, 259.00181765205116], [2707119.2593692904, 1093776.8218870184, 259.08751765205113], [2707118.390469291, 1093776.8411870184, 259.05241765205113], [2707115.2549692905, 1093776.9153870186, 259.12351765205113], [2707120.0702692904, 1093776.9311870185, 258.75931765205115], [2707117.5043692905, 1093776.7713870185, 259.0667176520512], [2707120.1600692905, 1093776.4387870184, 258.98301765205116], [2707116.0534692905, 1093776.9011870185, 259.0565176520512]]
# File read and converted in: 5.044540999999981
# Filtering
#  15%|█▌        | 112292/736474 [00:00<00:02, 222224.69it/s]
# Filtering done
# Filtered_data1_list len:  112292
# Filtering done in:  0.5098749000001135
# Saving filtered data to C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_1.txt...
# Done saving filtered data
# Constraining cloud C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\river_2.txt
# Output cloud C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_2.txt
# Data loaded
# Data1:  957402
# data1_list length:  957402
# data1_list[:10]:  [[2707100.8, 1093803.9199932863, 253.1900000667572], [2707100.97, 1093802.8099932862, 253.05000006675718], [2707099.67, 1093803.499993286, 253.1300000667572], [2707099.07, 1093803.729993286, 253.1200000667572], [2707098.67, 1093802.8899932862, 253.05000006675718], [2707098.14, 1093804.3099932862, 253.1000000667572], [2707098.29, 1093803.3599932862, 253.1300000667572], [2707100.75, 1093802.3299932862, 253.0400000667572], [2707099.82, 1093802.519993286, 253.0900000667572], [2707099.23, 1093802.6399932862, 253.02000006675718]]
# File read and converted in: 5.526374900000064
# Filtering
#  15%|█▌        | 143887/957402 [00:00<00:03, 254963.21it/s]
# Filtering done
# Filtered_data1_list len:  143887
# Filtering done in:  0.5699481999999989
# Saving filtered data to C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_2.txt...
# Done saving filtered data
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_1.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_2.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_3.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_4.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_5.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_6.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_7.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_8.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_9.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_10.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_11.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_12.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_13.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_14.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_15.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_16.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_17.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_18.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_19.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_20.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_21.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_22.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_23.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_24.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_25.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_26.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_27.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_28.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_29.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_2_30.las
#  Job finished
# Done
# Calculating box number 1
# Constraining cloud C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\river_1.txt
# Output cloud C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_1.txt
# Data loaded
# Data1:  736474
# data1_list length:  736474
# data1_list[:10]:  [[2707118.8215692905, 1093776.8059870184, 259.0814176520512], [2707119.7413692907, 1093776.6804870185, 258.95931765205114], [2707120.5755692907, 1093776.4740870185, 259.00181765205116], [2707119.2593692904, 1093776.8218870184, 259.08751765205113], [2707118.390469291, 1093776.8411870184, 259.05241765205113], [2707115.2549692905, 1093776.9153870186, 259.12351765205113], [2707120.0702692904, 1093776.9311870185, 258.75931765205115], [2707117.5043692905, 1093776.7713870185, 259.0667176520512], [2707120.1600692905, 1093776.4387870184, 258.98301765205116], [2707116.0534692905, 1093776.9011870185, 259.0565176520512]]
# File read and converted in: 6.381713899999795
# Filtering
#  11%|█▏        | 83051/736474 [00:00<00:02, 299355.50it/s]
# Filtering done
# Filtered_data1_list len:  83051
# Filtering done in:  0.28216359999987617
# Saving filtered data to C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_1.txt...
# Done saving filtered data
# Constraining cloud C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\river_2.txt
# Output cloud C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_2.txt
# Data loaded
# Data1:  957402
# data1_list length:  957402
# ...
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_3_11.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_3_12.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_3_13.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_3_14.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_3_15.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_3_16.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_3_17.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_3_18.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_3_19.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_3_20.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_3_21.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_3_22.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_3_23.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_3_24.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_3_25.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_3_26.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_3_27.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_3_28.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_3_29.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/dataFolder/parametersTests/output_3_30.las
#  Job finished
# Done
# Calculating box number 1
# Constraining cloud C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\river_1.txt
# Output cloud C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_1.txt
# Data loaded
# Data1:  736474
# data1_list length:  736474
# data1_list[:10]:  [[2707118.8215692905, 1093776.8059870184, 259.0814176520512], [2707119.7413692907, 1093776.6804870185, 258.95931765205114], [2707120.5755692907, 1093776.4740870185, 259.00181765205116], [2707119.2593692904, 1093776.8218870184, 259.08751765205113], [2707118.390469291, 1093776.8411870184, 259.05241765205113], [2707115.2549692905, 1093776.9153870186, 259.12351765205113], [2707120.0702692904, 1093776.9311870185, 258.75931765205115], [2707117.5043692905, 1093776.7713870185, 259.0667176520512], [2707120.1600692905, 1093776.4387870184, 258.98301765205116], [2707116.0534692905, 1093776.9011870185, 259.0565176520512]]
# File read and converted in: 4.796542600000066
# Filtering
#   0%|          | 0/736474 [00:00<?, ?it/s]
# Filtering done
# Filtered_data1_list len:  0
# Filtering done in:  0.3563300999999228
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17644\4169760084.py in <cell line: 10>()
#      51
#      52         #* Creating two new constrained clouds
# ---> 53         path_to_constrained_1 = ComputeClouds.constrainCloud(path_to_cloud=path_to_file_original_1, bounding_box_list=bounding_box_list, path_to_output_cloud=path_to_output_cloud_1)
#      54         path_to_constrained_2 = ComputeClouds.constrainCloud(path_to_cloud=path_to_file_original_2, bounding_box_list=bounding_box_list, path_to_output_cloud=path_to_output_cloud_2)
#      55         #* Loop for changing parameters
#
# c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\computeclouds\ComputeClouds.py in constrainCloud(path_to_cloud, path_to_output_cloud, bounding_box_list)
#     639     print("Filtered_data1_list len: ", len(filtered_data1_list))
#     640     print("Filtering done in: ", perf_counter() - time_now)
# --> 641     assert (
#     642         len(filtered_data1_list) > 1
#     643     ), "Filtering failed, check the bounding box"
#
# AssertionError: Filtering failed, check the bounding box

# %%
# X_glob =  2707309.209991
# Y_glob =  1093859.170044
# Z_glob =  274.464996
# X_delta = 100
# Y_delta = 100
# Z_delta = 100
# bounding_box_list=[X_glob - X_delta, X_glob + X_delta, Y_glob - Y_delta, Y_glob + Y_delta, Z_glob - Z_delta, Z_glob + Z_delta]
# path_to_output_cloud_1= r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_1.txt"
# path_to_output_cloud_2= r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_2.txt"
# path_to_file_original_1 = r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\river_1.txt"
# path_to_file_original_2 = r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\river_2.txt"
# nameOfFileOutput = ("dataFolder/parametersTests/output_MANUAL_TEST.las")

# path_to_constrained_1 = ComputeClouds.constrainCloud(path_to_cloud=path_to_file_original_1, bounding_box_list=bounding_box_list, path_to_output_cloud=path_to_output_cloud_1)
# path_to_constrained_2 = ComputeClouds.constrainCloud(path_to_cloud=path_to_file_original_2, bounding_box_list=bounding_box_list, path_to_output_cloud=path_to_output_cloud_2)
# ComputeClouds.calcM3C2(
#     firstCd=path_to_constrained_1,
#     secondCd=path_to_constrained_2,
#     parametersConfigFilePath=path_to_params_file,
#     nameOfFileOutput=nameOfFileOutput, verbose=True
# )

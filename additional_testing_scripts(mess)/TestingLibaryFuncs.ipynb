# %% [markdown]
# Libs

# %%
from datetime import datetime
import os,sys

sys.path.insert(1, 'C:/Users/szinp/Desktop/GIS_PROJECT/CloudComPy39_20220513/')


from CloudCompPy_Computing_CloudPoint.computeclouds import ComputeClouds
import cloudComPy as cc

# %%
cloud1_river = cc.loadPointCloud("../dataFolder/server_manual_testing/1_E_subsample.txt")
# cloud1_river = cc.loadPointCloud("./dataFolder/files_to_be_converted/river/1.las")
# print(cloud1_river.getName())
cloud2_river = cc.loadPointCloud("../dataFolder/server_manual_testing/2_E_subsample.txt")
# cloud2_river = cc.loadPointCloud("./dataFolder/files_to_be_converted/river/2.las")
# print(cloud2_river.getName())
path_to_params_file = r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt"
nameOfFileOutput = "".join(["dataFolder/parametersTests/output", "_BIGASSDATA_1.las"])

# %%
nameOfFileOutputWOLOLO = "".join(["dataFolder/parametersTests/output_WOLOLO", "_BIGASSDATA__TXT_1.las"])
ComputeClouds.calcM3C2(
    firstCd=cloud1_river,
    secondCd=cloud2_river,
    parametersConfigFilePath=path_to_params_file,
    nameOfFileOutput=nameOfFileOutputWOLOLO, verbose=False
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21820\3089996896.py in <cell line: 2>()
#       1 nameOfFileOutputWOLOLO = "".join(["dataFolder/parametersTests/output_WOLOLO", "_BIGASSDATA__TXT_1.las"])
# ----> 2 ComputeClouds.calcM3C2(
#       3     firstCd=cloud1_river,
#       4     secondCd=cloud2_river,
#       5     parametersConfigFilePath=path_to_params_file,
#
# C:\Users/szinp/Desktop/GIS_PROJECT/CloudComPy39_20220513\CloudCompPy_Computing_CloudPoint\computeclouds\ComputeClouds.py in calcM3C2(firstCd, secondCd, includeTimestamp, nameOfFileOutput, parametersConfigFilePath, alignICP, ICP_max_iterations, debugTest, verbose)
#     369     path2 = secondCd
#     370
# --> 371     assert os.path.isfile(
#     372         path1
#     373     ), "First cloud file does not exist. Check the path."
#
# c:\Users\szinp\anaconda3\envs\CloudComPy39\lib\genericpath.py in isfile(path)
#      28     """Test whether a path is a regular file"""
#      29     try:
# ---> 30         st = os.stat(path)
#      31     except (OSError, ValueError):
#      32         return False
#
# TypeError: stat: path should be string, bytes, os.PathLike or integer, not ccPointCloud

# %%
if cc.isPluginM3C2():
    import cloudComPy.M3C2
    ###* this is actually necesary for the plugin to work

    CloudAfterM3C2 = cc.M3C2.computeM3C2(
        [cloud1_river, cloud2_river], path_to_params_file
    )
    print("M3C2 plugin is loaded, attempting to run M3C2")
    cc.SavePointCloud(CloudAfterM3C2, nameOfFileOutput)

# %%
path_to_file_original_1 = r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\river_1.txt"
path_to_file_original_2 = r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\river_2.txt"

# path_to_file_original_1 = r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\1_E_subsample.txt"
# path_to_file_original_2 = r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\2_E_subsample.txt"

path_to_params_file = r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt"

assert os.path.isfile(path_to_file_original_1), "File does not exist"
assert os.path.isfile(path_to_file_original_2), "File does not exist"
assert os.path.isfile(path_to_params_file), "File does not exist"
print("Paths are loaded", datetime.now() )
# Out:
# Paths are loaded 2022-07-25 15:45:11.386059

# %% [markdown]
# ### Parameters to change

# %%
m3c2_params_dic={}

m3c2_params_dic["M3C2VER"]= 1
m3c2_params_dic["NormalMode"]= 0
m3c2_params_dic["NormalScale"]= 10.691401
m3c2_params_dic["NormalMinScale"]= 5.3457
m3c2_params_dic["NormalStep"]= 5.3457
m3c2_params_dic["NormalMaxScale"]= 21.382801
m3c2_params_dic["SearchScale"]= 5.3457
m3c2_params_dic["SearchDepth"]= 41.898286
m3c2_params_dic["SubsampleRadius"]= 2.67285
m3c2_params_dic["NormalPreferedOri"]= 4
m3c2_params_dic["NormalUseCorePoints"]= "true"
m3c2_params_dic["SubsampleEnabled"]= "false"
m3c2_params_dic["RegistrationError"]= 0
m3c2_params_dic["RegistrationErrorEnabled"]= "false"
m3c2_params_dic["UseSinglePass4Depth"]= "false"
m3c2_params_dic["PositiveSearchOnly"]= "false"
m3c2_params_dic["UseMedian"]= "false"
m3c2_params_dic["UseMinPoints4Stat"]= "false"
m3c2_params_dic["MinPoints4Stat"]= 5
m3c2_params_dic["ProjDestIndex"]= 1
m3c2_params_dic["UseOriginalCloud"]= "false"
m3c2_params_dic["ExportStdDevInfo"]= "true"
m3c2_params_dic["ExportDensityAtProjScale"]= "true"
m3c2_params_dic["MaxThreadCount"]= 4
m3c2_params_dic["UsePrecisionMaps"]= "false"
m3c2_params_dic["PM1Scale"]= 1
m3c2_params_dic["PM2Scale"]= 1

# %%
# print(f"Writing parameters to {path_to_params_file}")

# with open(path_to_params_file, 'w') as f:
#     f.write("[General]\n")
#     for key,value in m3c2_params_dic.items():
#         f.write("%s=%s\n"%(key,value))

# %% [markdown]
# ### Constraining the cloud to a certain area

# %%
# #? data for the strap
# # Global center of the cloud
# X_glob =  503455.626160
# Y_glob =  4918094.496948
# Z_glob =  720.263306
# # dimmensions
# X_delta = 100
# Y_delta = 100
# Z_delta = 100
# # X: 683.566
# # Y: 522.363
# # Z: 345.093
# #                       c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint/constrained_cloud.txt...
# path_to_output_cloud_1= r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\output_cloud_1.txt"
# path_to_output_cloud_2= r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\output_cloud_2.txt"

# %% [markdown]
# ### Specifying the cloud size/ box size

# %%
# bounding_box_list=[X_glob - X_delta, X_glob + X_delta, Y_glob - Y_delta, Y_glob + Y_delta, Z_glob - Z_delta, Z_glob + Z_delta]

# %% [markdown]
# ### Creating clouds with specified size

# %%
# path_to_constrained_1 = ComputeClouds.constrainCloud(path_to_cloud=path_to_file_original_1, bounding_box_list=bounding_box_list, path_to_output_cloud=path_to_output_cloud_1)
# path_to_constrained_2 = ComputeClouds.constrainCloud(path_to_cloud=path_to_file_original_2, bounding_box_list=bounding_box_list, path_to_output_cloud=path_to_output_cloud_2)
# # path_to_constrained_1 = ComputeClouds.constrainCloud(path_to_cloud=path_to_file_original_1, bounding_box_list=bounding_box_list, path_to_output_cloud=path_to_output_cloud)

# %% [markdown]
# ### Looping over the parameters

# %%
# with open("./log_timing.log", 'a') as f:
# with open("./log_timing.log", 'w') as f:
#     f.write("[Parameters]\t[BoxSize]\t[Time]\n")


m3c2_params_dic={}
m3c2_params_dic["M3C2VER"]= 1
m3c2_params_dic["NormalMode"]= 0
m3c2_params_dic["NormalScale"]= 10.691401
m3c2_params_dic["NormalMinScale"]= 5.3457
m3c2_params_dic["NormalStep"]= 5.3457
m3c2_params_dic["NormalMaxScale"]= 21.382801
m3c2_params_dic["SearchScale"]= 5.3457
m3c2_params_dic["SearchDepth"]= 41.898286
m3c2_params_dic["SubsampleRadius"]= 2.67285
m3c2_params_dic["NormalPreferedOri"]= 4
m3c2_params_dic["NormalUseCorePoints"]= "true"
m3c2_params_dic["SubsampleEnabled"]= "false"
m3c2_params_dic["RegistrationError"]= 0
m3c2_params_dic["RegistrationErrorEnabled"]= "false"
m3c2_params_dic["UseSinglePass4Depth"]= "false"
m3c2_params_dic["PositiveSearchOnly"]= "false"
m3c2_params_dic["UseMedian"]= "false"
m3c2_params_dic["UseMinPoints4Stat"]= "false"
m3c2_params_dic["MinPoints4Stat"]= 5
m3c2_params_dic["ProjDestIndex"]= 1
m3c2_params_dic["UseOriginalCloud"]= "false"
m3c2_params_dic["ExportStdDevInfo"]= "true"
m3c2_params_dic["ExportDensityAtProjScale"]= "true"
m3c2_params_dic["MaxThreadCount"]= 4
m3c2_params_dic["UsePrecisionMaps"]= "false"
m3c2_params_dic["PM1Scale"]= 1
m3c2_params_dic["PM2Scale"]= 1

# M3C2VER = 1
# NormalMode = 0
# NormalScale = 10.691401
# NormalMinScale = 5.3457
# NormalStep = 5.3457
# NormalMaxScale = 21.382801
# SearchScale = 5.3457
# SearchDepth = 41.898286
# SubsampleRadius = 2.67285
# NormalPreferedOri = 4
# NormalUseCorePoints = true
# SubsampleEnabled = false
# RegistrationError = 0
# RegistrationErrorEnabled = false
# UseSinglePass4Depth = false
# PositiveSearchOnly = false
# UseMedian = false
# UseMinPoints4Stat = false
# MinPoints4Stat = 5
# ProjDestIndex = 1
# UseOriginalCloud = false
# ExportStdDevInfo = true
# ExportDensityAtProjScale = true
# MaxThreadCount = 4
# UsePrecisionMaps = false
# PM1Scale = 1
# PM2Scale = 1
ComputeClouds.overwrite_parameters(path_to_params_file, m3c2_params_dic)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5972\2784968098.py in <cell line: 62>()
#      60 # PM1Scale = 1
#      61 # PM2Scale = 1
# ---> 62 ComputeClouds.overwrite_parameters(path_to_params_file, m3c2_params_dic)
#
# NameError: name 'path_to_params_file' is not defined

# %% [markdown]
# ### Calculating M3C2

# %% [markdown]
# ```
# TODO:
# - created a bounding box for the cloud
# - logging for checking the performance
# - created m3c2 outputs for iterating parameters
# - repeated for moving the boudnign box (to see if performance/output changes)
# ```

# %%
# bounding_box_list_volume = (bounding_box_list[1] - bounding_box_list[0]) * (bounding_box_list[3] - bounding_box_list[2]) * (bounding_box_list[5] - bounding_box_list[4])

# %%
# my_file = open("this_is_file.txt","w+")
# my_file.write("Hello World")
# my_file.close()
path_for_logging = os.path.abspath(".")
path_for_logging_folder = path_for_logging + "\dataFolder\parametersTests"
volume = "_Volume_3_375_000"
if not os.path.exists(path_for_logging_folder):
    os.makedirs(path_for_logging_folder)
iteration : int = 0
for x in range(0,7):
    # Hack to avoid the first iteration
    if x<4:
        continue
    path_for_logging = path_for_logging_folder + "\log_timing_3_375_000_volume" + str(x+1) + ".log"
    with open(path_for_logging, "w+") as f:
        list_of_changed_params = []
        f.write("[NormalScale NormalMinScale NormalStep NormalMaxScale SearchScale SearchDepth SubsampleRadius]\t[BoxSize]\t[Time]\n")
        
        m3c2_params_dic["NormalScale"]= 3
        m3c2_params_dic["NormalMinScale"]= 3.3457
        m3c2_params_dic["NormalStep"]= 3.3457
        m3c2_params_dic["NormalMaxScale"]= 13.382801
        m3c2_params_dic["SearchScale"]= 5
        m3c2_params_dic["SearchDepth"]= 13.898286
        m3c2_params_dic["SubsampleRadius"]= 0.67285

        # dimmensions
        # Once variant for checking if the box size matter
        if x >= 4:
            print("Calculating box number 2")
            X_glob =  2707309.209991 + iteration*10
            Y_glob =  1093859.170044
            Z_glob =  274.464996
            X_delta = 50+125
            Y_delta = 50+125
            Z_delta = 50+125
            iteration += 1
        else:
            print("Calculating box number 1")
            X_glob =  2707309.209991 + x*25
            Y_glob =  1093859.170044 - x*25
            Z_glob =  274.464996 - x*25
            X_delta = 50
            Y_delta = 50
            Z_delta = 50

        path_to_output_cloud_1= r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_1.txt"
        path_to_output_cloud_2= r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_2.txt"

        bounding_box_list=[X_glob - X_delta, X_glob + X_delta, Y_glob - Y_delta, Y_glob + Y_delta, Z_glob - Z_delta, Z_glob + Z_delta]
        bounding_box_list_volume = (bounding_box_list[1] - bounding_box_list[0]) * (bounding_box_list[3] - bounding_box_list[2]) * (bounding_box_list[5] - bounding_box_list[4])

        #* Creating two new constrained clouds
        path_to_constrained_1 = ComputeClouds.constrainCloud(path_to_cloud=path_to_file_original_1, bounding_box_list=bounding_box_list, path_to_output_cloud=path_to_output_cloud_1)
        path_to_constrained_2 = ComputeClouds.constrainCloud(path_to_cloud=path_to_file_original_2, bounding_box_list=bounding_box_list, path_to_output_cloud=path_to_output_cloud_2)
        #* Loop for changing parameters
        for iteration in range(1, 31):
            # * parameters to be changed
            # * rest of them are declared earlier
            nameOfFileOutput = "".join(["dataFolder/parametersTests/output", volume,  str(x+1), "_", str(iteration), ".las"])
            # nameOfFileOutput = (
            #     "dataFolder/parametersTests/output" + "_V3_375_000" +  str(x+1) + "_"+ str(iteration) + ".las"
            # )
            m3c2_params_dic["NormalScale"] += 1
            m3c2_params_dic["NormalMinScale"] += 1
            m3c2_params_dic["NormalStep"] += 1
            m3c2_params_dic["NormalMaxScale"] += 1
            m3c2_params_dic["SearchScale"] += 1
            # m3c2_params_dic["SearchDepth"] += 1
            m3c2_params_dic["SubsampleRadius"] += 1
            list_of_changed_params = [
                m3c2_params_dic["NormalScale"],
                m3c2_params_dic["NormalMinScale"],
                m3c2_params_dic["NormalStep"],
                m3c2_params_dic["NormalMaxScale"],
                m3c2_params_dic["SearchScale"],
                m3c2_params_dic["SearchDepth"],
                m3c2_params_dic["SubsampleRadius"],
            ]

            # * create new parameters file
            ComputeClouds.overwrite_parameters(
                path_to_params_file, m3c2_params_dic
            )
            # * run M3C2
            time_startM3C2 = ComputeClouds.perf_counter()
            ComputeClouds.calcM3C2(
                firstCd=path_to_constrained_1,
                secondCd=path_to_constrained_2,
                parametersConfigFilePath=path_to_params_file,
                nameOfFileOutput=nameOfFileOutput, verbose=False
            )
            time_endM3C2 = ComputeClouds.perf_counter() - time_startM3C2
            f.write(
                f"{list_of_changed_params}\t{bounding_box_list_volume}\t{time_endM3C2}\n"
            )

        print("Done")
# Out:
# Calculating box number 2
# Constraining cloud C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\river_1.txt
# Output cloud C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_1.txt
# Data loaded
# Data1:  736474
# data1_list length:  736474
# data1_list[:10]:  [[2707118.8215692905, 1093776.8059870184, 259.0814176520512], [2707119.7413692907, 1093776.6804870185, 258.95931765205114], [2707120.5755692907, 1093776.4740870185, 259.00181765205116], [2707119.2593692904, 1093776.8218870184, 259.08751765205113], [2707118.390469291, 1093776.8411870184, 259.05241765205113], [2707115.2549692905, 1093776.9153870186, 259.12351765205113], [2707120.0702692904, 1093776.9311870185, 258.75931765205115], [2707117.5043692905, 1093776.7713870185, 259.0667176520512], [2707120.1600692905, 1093776.4387870184, 258.98301765205116], [2707116.0534692905, 1093776.9011870185, 259.0565176520512]]
# File read and converted in: 11.751892499999997
# Filtering
#  85%|████████▍ | 622988/736474 [00:02<00:00, 298000.95it/s]
# Filtering done
# Filtered_data1_list len:  622988
# Filtering done in:  2.130665300000004
# Saving filtered data to C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_1.txt...
# Done saving filtered data
# Constraining cloud C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\river_2.txt
# Output cloud C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_2.txt
# Data loaded
# Data1:  957402
# data1_list length:  957402
# data1_list[:10]:  [[2707100.8, 1093803.9199932863, 253.1900000667572], [2707100.97, 1093802.8099932862, 253.05000006675718], [2707099.67, 1093803.499993286, 253.1300000667572], [2707099.07, 1093803.729993286, 253.1200000667572], [2707098.67, 1093802.8899932862, 253.05000006675718], [2707098.14, 1093804.3099932862, 253.1000000667572], [2707098.29, 1093803.3599932862, 253.1300000667572], [2707100.75, 1093802.3299932862, 253.0400000667572], [2707099.82, 1093802.519993286, 253.0900000667572], [2707099.23, 1093802.6399932862, 253.02000006675718]]
# File read and converted in: 6.3593667000000025
# Filtering
#  83%|████████▎ | 795722/957402 [00:01<00:00, 417493.47it/s]
# Filtering done
# Filtered_data1_list len:  795722
# Filtering done in:  1.9135248999999988
# Saving filtered data to C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_2.txt...
# Done saving filtered data
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\parametersTests\output_Volume_3_375_0005_1.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\parametersTests\output_Volume_3_375_0005_2.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\parametersTests\output_Volume_3_375_0005_3.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\parametersTests\output_Volume_3_375_0005_4.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\parametersTests\output_Volume_3_375_0005_5.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\parametersTests\output_Volume_3_375_0005_6.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\parametersTests\output_Volume_3_375_0005_7.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\parametersTests\output_Volume_3_375_0005_8.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\parametersTests\output_Volume_3_375_0005_9.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\parametersTests\output_Volume_3_375_0005_10.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\parametersTests\output_Volume_3_375_0005_11.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\parametersTests\output_Volume_3_375_0005_12.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\parametersTests\output_Volume_3_375_0005_13.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\parametersTests\output_Volume_3_375_0005_14.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\parametersTests\output_Volume_3_375_0005_15.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\parametersTests\output_Volume_3_375_0005_16.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\parametersTests\output_Volume_3_375_0005_17.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\parametersTests\output_Volume_3_375_0005_18.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\parametersTests\output_Volume_3_375_0005_19.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...
#  Loading finished
#  Reading params from C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Searching for M3C2 plugin in enviroment...
#  M3C2 plugin is loaded, attempting to run M3C2
#  M3C2 plugin work finished
# Saving results to c:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\parametersTests\output_Volume_3_375_0005_20.las
#  Job finished
#  parametersConfigFilePath _>
#  C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\PythonParameters\m3c2_params.txt
#  Paths are correct
#  Loading clouds into CloudComPy...

# %%
# X_glob =  2707309.209991
# Y_glob =  1093859.170044
# Z_glob =  274.464996
# X_delta = 100
# Y_delta = 100
# Z_delta = 100
# bounding_box_list=[X_glob - X_delta, X_glob + X_delta, Y_glob - Y_delta, Y_glob + Y_delta, Z_glob - Z_delta, Z_glob + Z_delta]
# path_to_output_cloud_1= r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_1.txt"
# path_to_output_cloud_2= r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\tmp_constrained_cloud_2.txt"
# path_to_file_original_1 = r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\river_1.txt"
# path_to_file_original_2 = r"C:\Users\szinp\Desktop\GIS_PROJECT\CloudComPy39_20220513\CloudCompPy_Computing-CloudPoint\dataFolder\pythonScripts_testInputs\river_2.txt"
# nameOfFileOutput = ("dataFolder/parametersTests/output_MANUAL_TEST.las")

# path_to_constrained_1 = ComputeClouds.constrainCloud(path_to_cloud=path_to_file_original_1, bounding_box_list=bounding_box_list, path_to_output_cloud=path_to_output_cloud_1)
# path_to_constrained_2 = ComputeClouds.constrainCloud(path_to_cloud=path_to_file_original_2, bounding_box_list=bounding_box_list, path_to_output_cloud=path_to_output_cloud_2)
# ComputeClouds.calcM3C2(
#     firstCd=path_to_constrained_1,
#     secondCd=path_to_constrained_2,
#     parametersConfigFilePath=path_to_params_file,
#     nameOfFileOutput=nameOfFileOutput, verbose=True
# )
